# %% [markdown]
# <a href="https://colab.research.google.com/github/Sudipta-Mitra/Stock-Price-Trend-Prediction-with-LSTM/blob/main/Download_Reliance_Industries_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install yfinance if not already installed
# pip install yfinance pandas matplotlib

import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Step 1: Download Reliance Industries data
# NSE ticker symbol for Reliance: "RELIANCE.NS"
# (for BSE, use "RELIANCE.BO")
# --------------------------
ticker = "RELIANCE.NS"
reliance = yf.download(ticker, start="2010-01-01", end="2025-01-01", interval="1d")
# Out:
# /tmp/ipython-input-1279280762.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   reliance = yf.download(ticker, start="2010-01-01", end="2025-01-01", interval="1d")
# [*********************100%***********************]  1 of 1 completed

# %%
print(reliance.head())
print(reliance.tail())
# Out:
# Price            Close        High         Low        Open      Volume
# Ticker     RELIANCE.NS RELIANCE.NS RELIANCE.NS RELIANCE.NS RELIANCE.NS
# Date
# 2010-01-04  218.593094  221.763765  207.688857  221.763765    76646086
# 2010-01-05  217.617523  233.714773  216.540313  233.714773    21392825
# 2010-01-06  221.133682  222.454796  217.607324  219.487367    23691760
# 2010-01-07  224.802307  226.621378  219.101204  221.133693    26197920
# 2010-01-08  224.212875  226.377471  222.759654  225.198627    15110149
# Price             Close         High          Low         Open      Volume
# Ticker      RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS RELIANCE.NS
# Date
# 2024-12-24  1217.885864  1228.642950  1216.142826  1217.437703     6734917
# 2024-12-26  1211.710571  1222.816119  1209.419672  1219.379892    10016178
# 2024-12-27  1216.192749  1223.015476  1212.158811  1213.453688     7000397
# 2024-12-30  1205.883789  1218.334064  1203.294156  1211.561187     8818766
# ...

# %%
reliance.to_csv("reliance_ohlcv.csv")

# %%
plt.figure(figsize=(12,6))
plt.plot(reliance.index, reliance["Close"], label="Reliance Close Price")
plt.title("Reliance Industries Stock (2010–2025)")
plt.xlabel("Date")
plt.ylabel("Price (INR)")
plt.legend()
plt.show()

# %%
df = pd.read_csv("reliance_ohlcv.csv")

# %%
df.head()
# Out:
#         Price               Close                High                 Low  \
# 0      Ticker         RELIANCE.NS         RELIANCE.NS         RELIANCE.NS
# 1        Date                 NaN                 NaN                 NaN
# 2  2010-01-04   218.5930938720703  221.76376542820617  207.68885732873463
# 3  2010-01-05  217.61752319335938   233.7147728475599   216.5403128968154
# 4  2010-01-06  221.13368225097656   222.4547964156801  217.60732377724915
#
#                  Open       Volume
# 0         RELIANCE.NS  RELIANCE.NS
# 1                 NaN          NaN
# 2  221.76376542820617     76646086
# 3   233.7147728475599     21392825
# 4  219.48736720498377     23691760
